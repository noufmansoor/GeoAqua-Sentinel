# %% [markdown]
# # 🌊 Water quality, Inland & coastal water intelligence
# ## Arab Youth Space Hackathon: 813 Challenge — Planet Tanager Hyperspectral Explorer
#
# This notebook explores **Planet's Tanager hyperspectral satellite** for mapping **Water quality, Inland & coastal water intelligence** water quality such as water turbidity, and algae blooms.
#
# ---
#
# ## What You Will Learn
#
# - How hyperspectral data reveals biodiversity-related spectral traits
# - How to compute indices linked to ecosystem function
# - How to monitor the water turbidity which is a good indication of the water health.
# - How to identify potential harmful algal blooms (HABs)
#
# ---
#
# 🌊 Why Water Quality Monitoring?
# Water quality is a critical indicator of ecosystem health in coastal and inland environments. Monitoring water conditions helps detect:
#
# Harmful algal blooms (HABs) that impact marine life and public health
# Suspended sediments and turbidity affecting water clarity
# Pollution events such as runoff, industrial discharge, or dredging
#
# These processes directly influence:
#
# Fisheries and aquaculture
# Coastal ecosystem stability
# Human health and water resource management
#
#
# 🛰 Why Hyperspectral Data (Tanager)?
# Tanager’s hyperspectral capability enables advanced water analysis beyond traditional imagery:
#
# Detect algal blooms by identifying chlorophyll and pigment signatures
# Measure turbidity and sediment plumes through spectral scattering patterns
# Differentiate water types (clear, turbid, polluted, shallow) using fine spectral resolution
# Identify early changes in water conditions before they are visible in standard RGB imagery
#
#
# 🎯 Key Advantage
# 👉 Unlike multispectral data, hyperspectral imagery provides continuous spectral information, allowing:
#
# More accurate water quality classification
# Detection of subtle chemical and biological signals
# Better monitoring of coastal dynamics and pollution impacts
#
# ---
#
# ## Relevant STAC Collection
#
# ```
# https://www.planet.com/data/stac/tanager-core-imagery/coastal-water-bodies/collection.json
# ```

# %% [markdown]
# ### 👋 First time here?
#
# If this is your first notebook in the repo, we recommend starting with `00_EO_data_quickstart_notebook.ipynb` first. It walks through environment setup, key concepts (STAC, COGs, bands, hyperspectral vs. multispectral), and includes a troubleshooting guide that applies to all the notebooks here.
#
# That said, this notebook is self-contained — the `%pip install` cell below installs everything it needs, so it will still run fine on its own (e.g. directly in Google Colab).
#
# ---

# %%
# %pip install pystac-client planetary-computer stackstac rasterio xarray matplotlib geopandas leafmap ipywidgets rioxarray h5py requests
# Out:
# Collecting pystac-client
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting planetary-computer
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting stackstac
#   Downloading stackstac-0.5.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.13/dist-packages (1.5.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.13/dist-packages (2025.12.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.13/dist-packages (1.1.4)
# Collecting leafmap
#   Downloading leafmap-0.63.1-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.13/dist-packages (7.7.1)
# Collecting rioxarray
#   Downloading rioxarray-0.23.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.13/dist-packages (3.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (2.32.4)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac-1.15.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pystac-client) (2.9.0.post0)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.13/dist-packages (from planetary-computer) (8.5.0)
# Requirement already satisfied: pydantic>=1.7.3 in /usr/local/lib/python3.13/dist-packages (from planetary-computer) (2.13.5)
# Requirement already satisfied: pytz>=2020.5 in /usr/local/lib/python3.13/dist-packages (from planetary-computer) (2025.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from planetary-computer) (26.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.13/dist-packages (from planetary-computer) (1.2.3)
# Requirement already satisfied: dask>=2022.1.1 in /usr/local/lib/python3.13/dist-packages (from dask[array]>=2022.1.1->stackstac) (2026.8.0)
# Requirement already satisfied: numpy<3,>1.23 in /usr/local/lib/python3.13/dist-packages (from stackstac) (2.1.3)
# Requirement already satisfied: pandas<3,>=2 in /usr/local/lib/python3.13/dist-packages (from stackstac) (2.2.3)
# Requirement already satisfied: pyproj<4.0.0,>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from stackstac) (3.7.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.13/dist-packages (from rasterio) (3.0.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.13/dist-packages (from rasterio) (26.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from rasterio) (2026.7.22)
# Requirement already satisfied: pyparsing>=3.0 in /usr/local/lib/python3.13/dist-packages (from rasterio) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.13/dist-packages (from geopandas) (0.13.0)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.13/dist-packages (from leafmap) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.13/dist-packages (from leafmap) (0.12.47)
# Collecting duckdb>=1.4.1 (from leafmap)
#   Downloading duckdb-1.5.5-cp313-cp313-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.13/dist-packages (from leafmap) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.13/dist-packages (from leafmap) (5.2.2)
# Collecting geojson (from leafmap)
#   Downloading geojson-3.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from leafmap) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.13/dist-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.13/dist-packages (from leafmap) (0.20.0)
# Collecting ipyvue>=1.12.0 (from leafmap)
#   Downloading ipyvue-3.0.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting ipyvuetify (from leafmap)
#   Downloading ipyvuetify-3.0.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Collecting maplibre (from leafmap)
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.13/dist-packages (from leafmap) (5.24.1)
# Requirement already satisfied: python-box in /usr/local/lib/python3.13/dist-packages (from leafmap) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.13/dist-packages (from leafmap) (0.11.2)
# Collecting whiteboxgui (from leafmap)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.13/dist-packages (from leafmap) (2026.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets) (3.0.17)
# Collecting xarray
#   Downloading xarray-2026.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (2025.12.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (1.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.13/dist-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (0.12.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.5.7)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets) (80.10.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=2->stackstac) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.7.3->planetary-computer) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.7.3->planetary-computer) (2.46.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.7.3->planetary-computer) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=1.7.3->planetary-computer) (0.4.4)
# Collecting pystac-core<2,>=1.15.0 (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_core-1.15.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting pystac-ext-classification (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_classification-2.0.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-datacube (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_datacube-2.2.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-eo (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_eo-1.1.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-file (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_file-2.1.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-grid (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_grid-1.1.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-item-assets (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_item_assets-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-label (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_label-1.0.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-mgrs (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_mgrs-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-mlm (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_mlm-1.4.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting pystac-ext-pointcloud (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_pointcloud-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-projection (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_projection-2.0.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-raster (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_raster-1.1.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-render (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_render-2.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-sar (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_sar-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-sat (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_sat-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-scientific (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_scientific-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-storage (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_storage-2.0.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-table (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_table-1.2.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-timestamps (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_timestamps-1.1.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-version (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_version-1.2.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-view (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_view-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-xarray-assets (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client)
#   Downloading pystac_ext_xarray_assets-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.13/dist-packages (from pystac[validation]>=1.10.0->pystac-client) (4.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pystac-client) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.13/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.7)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.13/dist-packages (from anywidget->leafmap) (0.15.1)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.13/dist-packages (from bqplot->leafmap) (0.2.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from folium->leafmap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.13/dist-packages (from folium->leafmap) (3.1.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from gdown->leafmap) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from gdown->leafmap) (3.32.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from gdown->leafmap) (4.67.3)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.13/dist-packages (from ipyleaflet->leafmap) (0.20.0)
# Collecting eval-type-backport (from maplibre->leafmap)
#   Downloading eval_type_backport-0.4.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from plotly->leafmap) (9.1.4)
# Collecting ipytree (from whiteboxgui->leafmap)
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting whitebox (from whiteboxgui->leafmap)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2>=2.9->folium->leafmap) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (2026.6.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.11.1)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.26.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.13/dist-packages (from partd>=1.4.0->dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->gdown->leafmap) (2.9.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.13/dist-packages (from requests[socks]->gdown->leafmap) (1.7.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.11.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.13/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.13/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (26.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.13/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.20.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.14.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.9.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.2.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.13/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.4.0)
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.3 MB/s eta 0:00:00
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading stackstac-0.5.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 5.3 MB/s eta 0:00:00
# Downloading leafmap-0.63.1-py2.py3-none-any.whl (669 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.2/669.2 kB 18.5 MB/s eta 0:00:00
# Downloading rioxarray-0.23.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 5.6 MB/s eta 0:00:00
# Downloading xarray-2026.7.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.9 MB/s eta 0:00:00
# Downloading duckdb-1.5.5-cp313-cp313-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 70.1 MB/s eta 0:00:00
# Downloading ipyvue-3.0.0-py2.py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 111.4 MB/s eta 0:00:00
# Downloading pystac-1.15.2-py3-none-any.whl (5.7 kB)
# Downloading geojson-3.3.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-3.0.0-py2.py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 90.2 MB/s eta 0:00:00
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 63.7 MB/s eta 0:00:00
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.1 MB/s eta 0:00:00
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 22.7 MB/s eta 0:00:00
# Downloading pystac_core-1.15.2-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 10.6 MB/s eta 0:00:00
# Downloading eval_type_backport-0.4.0-py3-none-any.whl (6.4 kB)
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.7 MB/s eta 0:00:00
# Downloading pystac_ext_classification-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading pystac_ext_datacube-2.2.1-py3-none-any.whl (7.1 kB)
# Downloading pystac_ext_eo-1.1.1-py3-none-any.whl (7.7 kB)
# Downloading pystac_ext_file-2.1.1-py3-none-any.whl (5.8 kB)
# Downloading pystac_ext_grid-1.1.1-py3-none-any.whl (3.6 kB)
# Downloading pystac_ext_item_assets-1.0.1-py3-none-any.whl (3.7 kB)
# Downloading pystac_ext_label-1.0.2-py3-none-any.whl (8.2 kB)
# Downloading pystac_ext_mgrs-1.0.1-py3-none-any.whl (4.1 kB)
# Downloading pystac_ext_mlm-1.4.1-py3-none-any.whl (13 kB)
# Downloading pystac_ext_pointcloud-1.0.1-py3-none-any.whl (6.5 kB)
# Downloading pystac_ext_projection-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading pystac_ext_raster-1.1.1-py3-none-any.whl (6.8 kB)
# Downloading pystac_ext_render-2.0.0-py3-none-any.whl (5.0 kB)
# Downloading pystac_ext_sar-1.0.1-py3-none-any.whl (6.5 kB)
# Downloading pystac_ext_sat-1.0.1-py3-none-any.whl (4.9 kB)
# Downloading pystac_ext_scientific-1.0.1-py3-none-any.whl (5.5 kB)
# Downloading pystac_ext_storage-2.0.1-py3-none-any.whl (7.6 kB)
# Downloading pystac_ext_table-1.2.1-py3-none-any.whl (4.7 kB)
# Downloading pystac_ext_timestamps-1.1.1-py3-none-any.whl (4.6 kB)
# Downloading pystac_ext_version-1.2.1-py3-none-any.whl (5.8 kB)
# Downloading pystac_ext_view-1.0.1-py3-none-any.whl (4.8 kB)
# Downloading pystac_ext_xarray_assets-1.0.1-py3-none-any.whl (3.9 kB)
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: whitebox, jedi, geojson, eval-type-backport, duckdb, pystac-core, xarray, pystac-ext-xarray-assets, pystac-ext-view, pystac-ext-version, pystac-ext-timestamps, pystac-ext-table, pystac-ext-storage, pystac-ext-scientific, pystac-ext-sat, pystac-ext-sar, pystac-ext-render, pystac-ext-raster, pystac-ext-projection, pystac-ext-pointcloud, pystac-ext-mgrs, pystac-ext-label, pystac-ext-item-assets, pystac-ext-grid, pystac-ext-file, pystac-ext-datacube, maplibre, stackstac, rioxarray, pystac-ext-eo, pystac-ext-classification, pystac-ext-mlm, pystac, pystac-client, planetary-computer, ipyvue, ipytree, whiteboxgui, ipyvuetify, leafmap
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2025.12.0
#     Uninstalling xarray-2025.12.0:
#       Successfully uninstalled xarray-2025.12.0
# Successfully installed duckdb-1.5.5 eval-type-backport-0.4.0 geojson-3.3.0 ipytree-0.2.2 ipyvue-3.0.0 ipyvuetify-3.0.0 jedi-0.20.0 leafmap-0.63.1 maplibre-0.3.6 planetary-computer-1.0.0 pystac-1.15.2 pystac-client-0.9.0 pystac-core-1.15.2 pystac-ext-classification-2.0.1 pystac-ext-datacube-2.2.1 pystac-ext-eo-1.1.1 pystac-ext-file-2.1.1 pystac-ext-grid-1.1.1 pystac-ext-item-assets-1.0.1 pystac-ext-label-1.0.2 pystac-ext-mgrs-1.0.1 pystac-ext-mlm-1.4.1 pystac-ext-pointcloud-1.0.1 pystac-ext-projection-2.0.1 pystac-ext-raster-1.1.1 pystac-ext-render-2.0.0 pystac-ext-sar-1.0.1 pystac-ext-sat-1.0.1 pystac-ext-scientific-1.0.1 pystac-ext-storage-2.0.1 pystac-ext-table-1.2.1 pystac-ext-timestamps-1.1.1 pystac-ext-version-1.2.1 pystac-ext-view-1.0.1 pystac-ext-xarray-assets-1.0.1 rioxarray-0.23.0 stackstac-0.5.1 whitebox-2.3.6 whiteboxgui-2.3.0 xarray-2026.7.0

# %%
import os
# Reset leafmap titiler endpoint to the public instance.
# This prevents errors if Planetary Computer cells ran earlier in the session.
os.environ["TITILER_ENDPOINT"] = "https://titiler.xyz"

# %% [markdown]
# ## Step 1 – Load Items from the Coastal Water Bodies Collection
#
# We target scenes near the UAE and Arabian Gulf — one of the most ecologically important mangrove coasts in the Arabian Peninsula.

# %%
import requests

COLLECTION = "coastal-water-bodies"
item_ids = ["20250511_074311_00_4001", "20250223_165546_32_4001", "20250406_170447_47_4001"]

base = f"https://www.planet.com/data/stac/tanager-core-imagery/{COLLECTION}"
items = []
for iid in item_ids:
    url = f"{base}/{iid}/{iid}.json"
    r = requests.get(url, timeout=60)
    r.raise_for_status()
    items.append(r.json())
print(f"Loaded {len(items)} items from {COLLECTION}")

item = items[0]   # work with the first scene
# Out:
# Loaded 3 items from coastal-water-bodies

# %% [markdown]
# ## Step 2 – Inspect Scene Metadata

# %%
from IPython.display import Image
print("Scene ID:", item["id"])
print("Date    :", item["properties"]["datetime"])
print("Bbox    :", item["bbox"])
Image(url=item["assets"]["thumbnail"]["href"])
# Out:
# Scene ID: 20250511_074311_00_4001
# Date    : 2025-05-11T07:43:11Z
# Bbox    : [53.63200686177432, 23.990203106931855, 53.89428889725334, 24.192030163555803]
# <img src="https://storage.googleapis.com/open-cogs/planet-stac/tanager1-release2-core-imagery/thumbnail/20250511_074311_00_4001_thumb.png"/>

# %%
import json
print(json.dumps(item["properties"], indent=2))
# Out:
# {
#   "cloud_percent": 51,
#   "collection_mode": "standard_sensitivity",
#   "constellation": "Tanager",
#   "datetime": "2025-05-11T07:43:11Z",
#   "description": "All data products from Tanager-1 for 20250511_074311_00_4001 near Tarif, Al Dhafrah Region, Abu Dhabi Emirate, United Arab Emirates",
#   "gsd": 34.78,
#   "instruments": [
#     "4001"
#   ],
#   "license": "CC-BY-4.0",
#   "light_haze_percent": 0,
#   "location_description": "Tarif, Al Dhafrah Region, Abu Dhabi Emirate, United Arab Emirates",
#   "notes": null,
#   "platform": "Planet",
#   "plume_provider_ids": null,
#   "quality_category": "standard",
#   "title": "TanagerScene 20250511_074311_00_4001 Core Imagery",
#   "view:azimuth": 209.1,
#   "view:off_nadir": 25.8,
#   "view:sun_azimuth": 122.8,
#   "view:sun_elevation": 79.2
# }

# %% [markdown]
# ## Step 3 – Interactive Map

# %%
import leafmap, geopandas as gpd
from shapely.geometry import box

m = leafmap.Map(zoom=8)
ib = item["bbox"]
m.fit_bounds([[ib[1], ib[0]], [ib[3], ib[2]]])

# Scene footprint
gdf = gpd.GeoDataFrame({"geometry": [box(*ib)]}, crs="EPSG:4326")
m.add_gdf(gdf, layer_name="Scene footprint", style={"color":"yellow","fillOpacity":0})

# Visual COG overlay
for vk in ["ortho_visual", "visual", "rendered_preview"]:
    if vk in item.get("assets", {}):
        m.add_cog_layer(item["assets"][vk]["href"],
                        name=item["id"]+" (visual)",
                        titiler_endpoint="https://titiler.xyz")
        break

m
# Out:
# Map(center=[53.76307051625946, 24.091021936294148], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %% [markdown]
# ## Step 4 – Download Surface Reflectance

# %%
sr_key = "ortho_sr_hdf5" if "ortho_sr_hdf5" in item["assets"] else "basic_sr_hdf5"
sr_url = item["assets"][sr_key]["href"]
print("Using SR asset:", sr_key)
print("URL:", sr_url)

local_path = os.path.basename(sr_url)
if not os.path.exists(local_path):
    print("Downloading… (may take a few minutes)")
    with requests.get(sr_url, stream=True) as r:
        r.raise_for_status()
        with open(local_path, "wb") as fout:
            for chunk in r.iter_content(chunk_size=1024*1024):
                if chunk:
                    fout.write(chunk)
    print("Saved to:", local_path)
else:
    print("Already downloaded:", local_path)
# Out:
# Using SR asset: ortho_sr_hdf5
# URL: https://storage.googleapis.com/open-cogs/planet-stac/tanager1-release2-core-imagery/ortho_sr_hdf5/20250511_074311_00_4001_ortho_sr_hdf5.h5
# Downloading… (may take a few minutes)
# Saved to: 20250511_074311_00_4001_ortho_sr_hdf5.h5

# %% [markdown]
# ## Step 5 – Quality Masks

# %%
import h5py, numpy as np

root = "HDFEOS/GRIDS/HYP/Data Fields"
with h5py.File(local_path, "r") as f:
    cloud  = f[f"{root}/beta_cloud_mask"][:]
    nodata = f[f"{root}/nodata_pixels"][:]
    cirrus = f[f"{root}/beta_cirrus_mask"][:]

valid = (nodata == 0) & (cloud == 0) & (cirrus == 0)
print(f"Valid pixels: {valid.mean()*100:.1f}%")
print(f"Cloud cover:  {(cloud!=0).mean()*100:.1f}%")
# Out:
# Valid pixels: 38.6%
# Cloud cover:  40.6%

# %% [markdown]
# ## Step 6 – Extract Spectral Wavelengths

# %%
# Extract spectral wavelengths from STAC metadata.
# The key is "bands" and wavelengths are in micrometers under "eo:center_wavelength".
bands_meta = item["assets"][sr_key].get("bands", [])
spectral_bands = [b for b in bands_meta if "eo:center_wavelength" in b]
wavelengths_um = np.array([b["eo:center_wavelength"] for b in spectral_bands], dtype=float)
wavelengths_nm = wavelengths_um * 1000.0   # micrometers -> nanometers

print("Number of spectral bands:", len(wavelengths_nm))
print("First 10 wavelengths (nm):", np.round(wavelengths_nm[:10], 2))
print("Last  10 wavelengths (nm):", np.round(wavelengths_nm[-10:], 2))
# Out:
# Number of spectral bands: 426
# First 10 wavelengths (nm): [376.44 381.41 386.38 391.35 396.32 401.29 406.26 411.23 416.21 421.18]
# Last  10 wavelengths (nm): [2454.39 2459.35 2464.31 2469.26 2474.22 2479.18 2484.13 2489.09 2494.04
#  2499.  ]

# %% [markdown]
# ## Step 7 – Select Wavelengths for Ecosystem Monitoring
#
# | Index | Wavelengths | Target |
# |-------|------------|--------|
# | NDVI  | 665 nm Red, 800 nm NIR | General vegetation |
# | NDWI  | 560 nm Green, 860 nm NIR | Open water |
# | NDCI  | 665 nm Red, 708 nm Red-Edge | Chlorophyll / algae |
# | MMRI  | 560 nm Green, 665 nm Red, 708 nm RE, 800 nm NIR | Mangrove index |
# | Turbidity | 665 nm Red, 560 nm Green | Suspended sediment |

# %%
def pick_band(target_nm):
    idx = int(np.argmin(np.abs(wavelengths_nm - target_nm)))
    print(f"  Target {target_nm} nm → band {idx} ({wavelengths_nm[idx]:.1f} nm)")
    return idx, wavelengths_nm[idx]

print("Selecting bands:")
idx_b443, _ = pick_band(443)   # Coastal aerosol / deep water
idx_b560, _ = pick_band(560)   # Green — chlorophyll peak
idx_b665, _ = pick_band(665)   # Red
idx_b708, _ = pick_band(708)   # Red-edge — chlorophyll inflection
idx_b800, _ = pick_band(800)   # NIR — vegetation reflectance peak
idx_b860, _ = pick_band(860)   # NIR
# Out:
# Selecting bands:
#   Target 443 nm → band 13 (441.1 nm)
#   Target 560 nm → band 37 (560.8 nm)
#   Target 665 nm → band 58 (665.9 nm)
#   Target 708 nm → band 66 (705.9 nm)
#   Target 800 nm → band 85 (801.1 nm)
#   Target 860 nm → band 97 (861.3 nm)

# %% [markdown]
# ## Step 8 – Load Bands

# %%
root = "HDFEOS/GRIDS/HYP/Data Fields"

with h5py.File(local_path, "r") as f:
    sr = f[f"{root}/surface_reflectance"]
    R_443 = sr[idx_b443, :, :].astype("float32")
    R_560 = sr[idx_b560, :, :].astype("float32")
    R_665 = sr[idx_b665, :, :].astype("float32")
    R_708 = sr[idx_b708, :, :].astype("float32")
    R_800 = sr[idx_b800, :, :].astype("float32")
    R_860 = sr[idx_b860, :, :].astype("float32")

for arr in [R_443, R_560, R_665, R_708, R_800, R_860]:
    arr[~valid] = np.nan
    arr[arr < 0] = np.nan

# %% [markdown]
# ## Step 9 – Compute Ecosystem Indices

# %%
eps = 1e-6

# NDVI — general vegetation health
NDVI = (R_800 - R_665) / (R_800 + R_665 + eps)

# NDWI — water body detection
NDWI = (R_560 - R_860) / (R_560 + R_860 + eps)

# NDCI — Normalized Difference Chlorophyll Index
# Positive = chlorophyll present → potential algal bloom or dense aquatic vegetation
NDCI = (R_708 - R_665) / (R_708 + R_665 + eps)

# Turbidity proxy — suspended sediment in water
# High red relative to green → turbid / sediment-laden water
Turbidity = (R_665 - R_560) / (R_665 + R_560 + eps)

# Simple Mangrove Proxy: mangroves have high NIR + elevated red-edge
# Exclude open water (NDWI > 0) and low vegetation (NDVI < 0.2)
Mangrove_proxy = np.where((NDVI > 0.2) & (NDWI < 0), NDCI, np.nan)

# %% [markdown]
# ## Step 10 – Visualize

# %%
import matplotlib.pyplot as plt

# True RGB composite using Tanager surface reflectance bands
# R = 665 nm, G = 560 nm, B = 443 nm
# Percentile stretch so the image isn't washed out or too dark
def stretch(arr, p_low=2, p_high=98):
    lo, hi = np.nanpercentile(arr, p_low), np.nanpercentile(arr, p_high)
    return np.clip((arr - lo) / (hi - lo + 1e-6), 0, 1)

rgb_true = np.stack([
    stretch(R_665),   # Red channel
    stretch(R_560),   # Green channel
    stretch(R_443),   # Blue channel
], axis=-1)

# Replace NaN pixels with 0 for display
rgb_true = np.nan_to_num(rgb_true, nan=0.0)

# Create 2x2 figure
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# --- Top-left: NDCI ---
im1 = axes[0, 0].imshow(NDCI, cmap="YlGn", vmin=-0.2, vmax=0.4)
axes[0, 0].set_title("NDCI — Chlorophyll / Bloom Proxy")
axes[0, 0].axis("off")
fig.colorbar(im1, ax=axes[0, 0], fraction=0.046, pad=0.04)

# --- Top-right: Turbidity ---
im2 = axes[0, 1].imshow(Turbidity, cmap="inferno", vmin=-0.3, vmax=0.3)
axes[0, 1].set_title("Turbidity Proxy")
axes[0, 1].axis("off")
fig.colorbar(im2, ax=axes[0, 1], fraction=0.046, pad=0.04)

# --- Bottom-left: NDWI ---
im3 = axes[1, 0].imshow(NDWI, cmap="Blues", vmin=-0.5, vmax=0.8)
axes[1, 0].set_title("NDWI — Water Detection")
axes[1, 0].axis("off")
fig.colorbar(im3, ax=axes[1, 0], fraction=0.046, pad=0.04)

# --- Bottom-right: RGB ---
axes[1, 1].imshow(rgb_true)
axes[1, 1].set_title("True Colour RGB\n(R=665 nm, G=560 nm, B=443 nm)")
axes[1, 1].axis("off")

# Overall title
fig.suptitle("Tanager Ecosystem Health & Blue Carbon Indices", fontsize=14, fontweight="bold")

# Improve spacing
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ## Step 11 – Summary Statistics

# %%
def summarize(name, arr):
    valid_data = arr[~np.isnan(arr)]
    if len(valid_data) == 0:
        print(f"{name}: no valid data")
        return
    print(f"{name}: min={valid_data.min():.3f}  max={valid_data.max():.3f}  "
          f"mean={valid_data.mean():.3f}  std={valid_data.std():.3f}")

summarize("NDVI",      NDVI)
summarize("NDWI",      NDWI)
summarize("NDCI",      NDCI)
summarize("Turbidity", Turbidity)
# Out:
# NDVI: min=-0.676  max=0.393  mean=-0.306  std=0.192
# NDWI: min=-0.367  max=0.874  mean=0.636  std=0.232
# NDCI: min=-0.276  max=0.249  mean=-0.095  std=0.076
# Turbidity: min=-0.605  max=0.184  mean=-0.379  std=0.152

# %% [markdown]
# ## Step 12 – Mean Spectrum (Full Scene)
#
# The spectral signature integrates all land cover types in the scene.
# Look for the chlorophyll absorption dip at ~680 nm and the vegetation red-edge jump at ~720 nm.
#
# We exclude the two water-vapor absorption troughs (1350–1450 nm, 1800–1950 nm) plus wavelengths beyond 2450 nm, where the SWIR2 detector's edge channels and the collapsing atmospheric window otherwise produce erratic reflectance spikes rather than real surface signal.

# %%
def is_water_vapor(wl):
    return (1350 <= wl <= 1450) or (1800 <= wl <= 1950)

# Beyond ~2450 nm we're at the edge of the SWIR2 detector array: solar
# irradiance and atmospheric transmission both collapse toward the edge of
# the SWIR atmospheric window, and edge channels have the sensor's worst
# signal-to-noise ratio. Reflectance = radiance / irradiance blows up into
# noise there rather than showing real surface signal, so we drop that tail
# the same way we drop the water-vapor troughs.
SWIR_EDGE_NM = 2450

def is_bad_band(wl):
    return is_water_vapor(wl) or wl > SWIR_EDGE_NM

stride = 8
with h5py.File(local_path, "r") as f:
    sr = f[f"{root}/surface_reflectance"]
    good_idx = [i for i, w in enumerate(wavelengths_nm) if not is_bad_band(w)]
    cube = sr[good_idx, ::stride, ::stride].astype("float32")
    mask = valid[::stride, ::stride]
    cube[:, ~mask] = np.nan
    cube[cube < 0] = np.nan
    mean_spec = np.nanmean(cube, axis=(1,2))

wls = [wavelengths_nm[i] for i in good_idx]
plt.figure(figsize=(11,4))
plt.plot(wls, mean_spec, lw=1.4)
plt.xlabel("Wavelength (nm)"); plt.ylabel("Mean Surface Reflectance")
plt.title("Mean Spectrum — valid pixels, water-vapor & noisy SWIR-edge bands removed")
plt.grid(alpha=0.3); plt.tight_layout(); plt.show()

# %% [markdown]
# ### Spectral Signature of the Highest-Value Pixel per Index
#
# The plot above shows the **scene-average** spectrum. Now let's look at individual pixels: for each index (NDVI, NDWI, NDCI, Turbidity), we find the single pixel with the *highest* value — e.g. the densest coastal vegetation (NDVI), the clearest open water (NDWI), the strongest chlorophyll/algal-bloom signal (NDCI), and the most sediment-laden water (Turbidity) — and plot its full spectral signature (water-vapor bands removed). Comparing these extreme-pixel spectra side by side shows how differently these land-cover conditions reflect light across the spectrum.

# %%
# For the pixel with the single highest value of each index, read and plot its
# full spectral signature (reusing `good_idx`/`wls` from the cell above, which
# already exclude the water-vapor troughs and the noisy SWIR-edge tail).
#
# `good_idx` skips the excluded bands, so plain plt.plot(wls, ...) would draw
# a straight connecting line across those gaps. with_gaps() inserts a NaN
# wherever good_idx jumps by more than 1, so the line actually breaks there.
def with_gaps(band_idx, x, y):
    x_out, y_out = [x[0]], [y[0]]
    for k in range(1, len(band_idx)):
        if band_idx[k] != band_idx[k - 1] + 1:
            x_out.append((x[k - 1] + x[k]) / 2)
            y_out.append(np.nan)
        x_out.append(x[k]); y_out.append(y[k])
    return x_out, y_out

indices = {"NDVI": NDVI, "NDWI": NDWI, "NDCI": NDCI, "Turbidity": Turbidity}

plt.figure(figsize=(11, 5))
with h5py.File(local_path, "r") as f:
    sr = f[f"{root}/surface_reflectance"]
    for name, arr in indices.items():
        row, col = np.unravel_index(np.nanargmax(arr), arr.shape)
        pixel_spec = sr[good_idx, row, col].astype("float32")
        x_plot, y_plot = with_gaps(good_idx, wls, pixel_spec)
        plt.plot(x_plot, y_plot, lw=1.2, label=f"Highest {name}  (row={row}, col={col})")

plt.xlabel("Wavelength (nm)"); plt.ylabel("Surface Reflectance")
plt.title("Spectrum of the Highest-Value Pixel per Index — water-vapor & noisy SWIR-edge bands removed")
plt.legend(); plt.grid(alpha=0.3); plt.tight_layout(); plt.show()

# %% [markdown]
# ## Step 13 – Water vs Vegetation Spectral Comparison
#
# Compare the average spectrum of water pixels (NDWI > 0.1) vs vegetation pixels (NDVI > 0.3).

# %%
stride = 8
def is_water_vapor(wl):
    return (1350 <= wl <= 1450) or (1800 <= wl <= 1950)

# Beyond ~2450 nm we're at the edge of the SWIR2 detector array: solar
# irradiance and atmospheric transmission both collapse toward the edge of
# the SWIR atmospheric window, and edge channels have the sensor's worst
# signal-to-noise ratio. Reflectance = radiance / irradiance blows up into
# noise there rather than showing real surface signal, so we drop that tail
# the same way we drop the water-vapor troughs.
SWIR_EDGE_NM = 2450

def is_bad_band(wl):
    return is_water_vapor(wl) or wl > SWIR_EDGE_NM

good_idx = [i for i, w in enumerate(wavelengths_nm) if not is_bad_band(w)]
wls = [wavelengths_nm[i] for i in good_idx]

water_mask = (NDWI > 0.1) & valid
veg_mask   = (NDVI > 0.3) & valid

def mean_spec(mask):
    with h5py.File(local_path, "r") as f:
        sr = f[f"{root}/surface_reflectance"]
        cube = sr[good_idx, ::stride, ::stride].astype("float32")
    m = mask[::stride, ::stride]
    cube[:, ~m] = np.nan
    cube[cube < 0] = np.nan
    return [float(np.nanmean(cube[j])) for j in range(len(good_idx))]

spec_water = mean_spec(water_mask)
spec_veg   = mean_spec(veg_mask)

plt.figure(figsize=(11, 4))
plt.plot(wls, spec_veg,   color="green",  lw=1.5, label=f"Vegetation (NDVI>0.3, n~{veg_mask.sum()//stride**2:,}px)")
plt.plot(wls, spec_water, color="royalblue", lw=1.5, label=f"Water (NDWI>0.1, n~{water_mask.sum()//stride**2:,}px)")
plt.xlabel("Wavelength (nm)"); plt.ylabel("Mean Surface Reflectance")
plt.title("Spectral Signatures: Water vs Vegetation (SWIR-edge noise removed)")
plt.legend(); plt.grid(alpha=0.3); plt.tight_layout(); plt.show()

# %%
import pandas as pd

data = {
    "pH": [8.1, 8.0, 8.2, 7.9, 8.1, 6.5, 9.2, 7.0, 8.0, 8.1, 6.8, 8.2],
    "Turbidity_NTU": [2.1, 3.0, 2.5, 4.0, 3.5, 18.0, 15.0, 25.0, 4.0, 3.0, 20.0, 2.8],
    "Temperature_C": [27, 28, 29, 30, 28.5, 33, 34, 31, 29, 28, 32, 27.5],
    "TDS_mg_L": [38000, 39200, 40100, 39500, 38700, 46000, 44500, 48000, 39000, 38500, 47000, 39600],
    "Water_Flow_L_min": [50, 52, 49, 51, 48, 50, 53, 47, 22, 18, 25, 50],
    "Result": ["Normal", "Normal", "Normal", "Normal", "Normal",
               "Abnormal", "Abnormal", "Abnormal", "Abnormal",
               "Abnormal", "Abnormal", "Normal"]
}

water_data = pd.DataFrame(data)
water_data
# Out:
#      pH  Turbidity_NTU  Temperature_C  TDS_mg_L  Water_Flow_L_min    Result
# 0   8.1            2.1           27.0     38000                50    Normal
# 1   8.0            3.0           28.0     39200                52    Normal
# 2   8.2            2.5           29.0     40100                49    Normal
# 3   7.9            4.0           30.0     39500                51    Normal
# 4   8.1            3.5           28.5     38700                48    Normal
# 5   6.5           18.0           33.0     46000                50  Abnormal
# 6   9.2           15.0           34.0     44500                53  Abnormal
# 7   7.0           25.0           31.0     48000                47  Abnormal
# 8   8.0            4.0           29.0     39000                22  Abnormal
# 9   8.1            3.0           28.0     38500                18  Abnormal
# 10  6.8           20.0           32.0     47000                25  Abnormal
# 11  8.2            2.8           27.5     39600                50    Normal

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

normal = pd.DataFrame({
    "pH": np.random.uniform(7.7, 8.5, 250),
    "Turbidity_NTU": np.random.uniform(0.5, 5, 250),
    "Temperature_C": np.random.uniform(24, 31, 250),
    "TDS_mg_L": np.random.uniform(35000, 42000, 250),
    "Water_Flow_L_min": np.random.uniform(45, 55, 250),
    "Result": "Normal"
})

abnormal = pd.DataFrame({
    "pH": np.random.uniform(6.0, 9.5, 250),
    "Turbidity_NTU": np.random.uniform(10, 35, 250),
    "Temperature_C": np.random.uniform(30, 37, 250),
    "TDS_mg_L": np.random.uniform(43000, 52000, 250),
    "Water_Flow_L_min": np.random.uniform(10, 35, 250),
    "Result": "Abnormal"
})

water_data = pd.concat([normal, abnormal], ignore_index=True)
water_data = water_data.sample(frac=1, random_state=42).reset_index(drop=True)

print("Total records:", len(water_data))
water_data.head(10)
# Out:
# Total records: 500
#          pH  Turbidity_NTU  Temperature_C      TDS_mg_L  Water_Flow_L_min  \
# 0  6.737318      26.271934      34.593133  44818.141016         20.550857
# 1  8.352369       1.759703      28.354607  37787.180855         45.178739
# 2  6.865309      14.382574      35.129611  51856.992871         26.824166
# 3  7.893644       4.529855      24.893062  41248.701978         52.527166
# 4  8.426053       0.817559      24.844451  36435.977483         54.949078
# 5  7.179511      12.228111      33.885595  47240.511090         32.252426
# 6  7.801861      23.395692      33.558524  44493.594058         29.724629
# 7  7.882348       0.820349      28.327783  35177.704490         51.552420
# 8  7.759641       1.203967      30.329111  35383.331472         48.546222
# 9  7.740112      34.145554      30.620203  51791.202957         16.756192
#
#      Result
# 0  Abnormal
# 1    Normal
# 2  Abnormal
# 3    Normal
# 4    Normal
# 5  Abnormal
# 6  Abnormal
# 7    Normal
# 8    Normal
# 9  Abnormal

# %% [markdown]
# teaching the AI to identify normal and abnormal water.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

features = [
    "pH",
    "Turbidity_NTU",
    "Temperature_C",
    "TDS_mg_L",
    "Water_Flow_L_min"
]

X = water_data[features]
y = water_data["Result"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

model = RandomForestClassifier(
    n_estimators=100,
    max_depth=5,
    random_state=42
)

model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))

ConfusionMatrixDisplay.from_predictions(
    y_test,
    predictions,
    cmap="Blues"
)

plt.title("GeoAqua Sentinel AI Results")
plt.show()
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#     Abnormal       1.00      1.00      1.00        50
#       Normal       1.00      1.00      1.00        50
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %%
new_reading = pd.DataFrame([{
    "pH": 6.7,
    "Turbidity_NTU": 25,
    "Temperature_C": 35,
    "TDS_mg_L": 48000,
    "Water_Flow_L_min": 20
}])

result = model.predict(new_reading)[0]

print("AI Result:", result)

if result == "Abnormal":
    print("ALERT: Dangerous water condition detected!")
else:
    print("Water condition is normal.")
# Out:
# AI Result: Abnormal
# ALERT: Dangerous water condition detected!

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML
import pandas as pd

ph = widgets.FloatSlider(description="pH", min=5, max=10, value=8.1)
turbidity = widgets.FloatSlider(description="Turbidity", min=0, max=40, value=3)
temperature = widgets.FloatSlider(description="Temperature", min=20, max=40, value=28)
tds = widgets.FloatSlider(description="TDS", min=30000, max=55000, value=39000)
flow = widgets.FloatSlider(description="Flow Rate", min=0, max=60, value=50)

check_button = widgets.Button(
    description="Check Water",
    button_style="primary"
)

output = widgets.Output()

def check_water(button):
    sample = pd.DataFrame([{
        "pH": ph.value,
        "Turbidity_NTU": turbidity.value,
        "Temperature_C": temperature.value,
        "TDS_mg_L": tds.value,
        "Water_Flow_L_min": flow.value
    }])

    prediction = model.predict(sample)[0]

    with output:
        clear_output()

        if prediction == "Abnormal":
            display(HTML(
                "<h2 style='color:red;'>WARNING: Abnormal water detected</h2>"
            ))
        else:
            display(HTML(
                "<h2 style='color:green;'>Water condition is normal</h2>"
            ))

check_button.on_click(check_water)

display(HTML("<h2>GeoAqua Sentinel Water Dashboard</h2>"))
display(ph, turbidity, temperature, tds, flow, check_button, output)
# Out:
# <h2>GeoAqua Sentinel Water Dashboard</h2>
# FloatSlider(value=8.1, description='pH', max=10.0, min=5.0)
# FloatSlider(value=3.0, description='Turbidity', max=40.0)
# FloatSlider(value=28.0, description='Temperature', max=40.0, min=20.0)
# FloatSlider(value=39000.0, description='TDS', max=55000.0, min=30000.0)
# FloatSlider(value=50.0, description='Flow Rate', max=60.0)
# Button(button_style='primary', description='Check Water', style=ButtonStyle())
# Output()

# %%
import numpy as np

water_pixels = indices["NDWI"] > 0.1

satellite_ndci = np.nanpercentile(
    np.where(water_pixels, indices["NDCI"], np.nan),
    95
)

satellite_turbidity = np.nanpercentile(
    np.where(water_pixels, indices["Turbidity"], np.nan),
    95
)

iot_result = model.predict(new_reading)[0]

algae_warning = satellite_ndci > 0.2
turbidity_warning = satellite_turbidity > 0.1

print("Location: Tarif coastal area")
print("Satellite NDCI:", round(satellite_ndci, 3))
print("Satellite Turbidity:", round(satellite_turbidity, 3))
print("IoT and AI Result:", iot_result)

if iot_result == "Abnormal" or algae_warning or turbidity_warning:
    print("FINAL ALERT: Water inspection is required.")
else:
    print("FINAL RESULT: Water condition is normal.")
# Out:
# Location: Tarif coastal area
# Satellite NDCI: 0.009
# Satellite Turbidity: -0.169
# IoT and AI Result: Abnormal
# FINAL ALERT: Water inspection is required.

# %% [markdown]
# GeoAqua Sentinel PoC Summary
#
# Location: Tarif coastal area, Al Dhafra, Abu Dhabi.
#
# Problem: Water pollution, high turbidity, and algal blooms might remain unnoticed without continuous monitoring.
#
# Satellite data: The PoC uses Planet Tanager hyperspectral imagery to examine water, chlorophyll, and turbidity indicators.
#
# IoT data: The PoC uses 500 synthetic sensor records containing pH, turbidity, temperature, TDS, and water-flow measurements.
#
# AI model: A Random Forest model classifies water readings as normal or abnormal.
#
# Dashboard: Users enter water measurements and receive a normal result or a warning.
#
# Final result: The satellite did not show a strong warning in the selected image, but the test IoT readings were abnormal. The system requested a water inspection.
#
# Limitation: The current results use one satellite image and synthetic IoT data. Future testing should use real sensor measurements collected at the same location and time as the satellite image.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].imshow(indices["NDCI"], cmap="YlGn")
axes[0].set_title("Satellite Algal Bloom Indicator")
axes[0].axis("off")

axes[1].imshow(indices["Turbidity"], cmap="magma")
axes[1].set_title("Satellite Turbidity Indicator")
axes[1].axis("off")

axes[2].axis("off")
axes[2].text(
    0.05,
    0.90,
    "GeoAqua Sentinel Alert",
    fontsize=18,
    fontweight="bold"
)

axes[2].text(0.05, 0.75, "Location: Tarif coastal area", fontsize=12)
axes[2].text(0.05, 0.65, f"pH: {new_reading['pH'].iloc[0]}", fontsize=12)
axes[2].text(
    0.05,
    0.55,
    f"Turbidity: {new_reading['Turbidity_NTU'].iloc[0]} NTU",
    fontsize=12
)
axes[2].text(
    0.05,
    0.45,
    f"Temperature: {new_reading['Temperature_C'].iloc[0]} C",
    fontsize=12
)
axes[2].text(
    0.05,
    0.35,
    f"TDS: {new_reading['TDS_mg_L'].iloc[0]} mg/L",
    fontsize=12
)
axes[2].text(
    0.05,
    0.25,
    f"Flow rate: {new_reading['Water_Flow_L_min'].iloc[0]} L/min",
    fontsize=12
)

alert_color = "red" if iot_result == "Abnormal" else "green"

axes[2].text(
    0.05,
    0.10,
    f"AI Result: {iot_result}",
    fontsize=16,
    color=alert_color,
    fontweight="bold"
)

plt.suptitle(
    "GeoAqua Sentinel Combined Monitoring Dashboard",
    fontsize=20,
    fontweight="bold"
)

plt.tight_layout()
plt.show()

# %%
water_data.to_csv(
    "GeoAqua_Synthetic_IoT_Data.csv",
    index=False
)

fig.savefig(
    "GeoAqua_Sentinel_Dashboard.png",
    dpi=300,
    bbox_inches="tight"
)

print("Files saved successfully.")
# Out:
# Files saved successfully.

# %% [markdown]
# ---
# ## 🚀 Hackathon Challenge Ideas
#
# - **Mangrove area estimation** — threshold the Mangrove_proxy map and compute area in km²
# - **Algal bloom detection** — find pixels where NDCI > 0.2 within NDWI-positive water bodies
# - **Seagrass mapping** — shallow water with positive NDVI signature
# - **Carbon stock estimation** — combine mangrove extent with published carbon density values (t C/ha)
# - **Turbidity monitoring** — track sediment plumes from rivers or coastal construction
#
# ### 📊 Before You Submit: Think Like a Product, Not Just a Model
#
# A working technical demo is only half of a hackathon submission. Before you submit your Proof of Concept, make sure you can also answer:
#
# - **What real business problem does this solve, and for whom?** Who has this problem today, and what do they currently do about it without your solution?
# - **How good is your model, really?** Include concrete validation statistics for your PoC — accuracy, precision/recall, RMSE, IoU, or a comparison against ground truth/known events — not just "it looks right on the map."
# - **How will end users actually see your results?** You don't need to build a full frontend for the PoC, but you should be able to describe how your application would deliver value in practice — e.g. a dashboard, a REST API, an alerting/notification system, a scheduled report — and roughly what that would look like.
#
# ---
#
# > 📖 Created by: [LInkedin: Dr. Vincent Markiet - Space42](https://www.linkedin.com/in/vincentmarkiet/)
#
# > 📖 Data license: CC-BY-4.0 © Planet Labs PBC
